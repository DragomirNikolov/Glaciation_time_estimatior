# %%
import xarray as xr
import numpy as np

# %%
test_data=xr.open_dataset("/cluster/work/climate/dnikolo/CLAAS_Data/02_2004/CTT/CTXin20040120034500405SVMSG01MD.nc")

# %%
field=test_data.variables["ctt"].data

# %%
np.count_nonzero(np.isnan(field))/field.size
# Out:
# 0.45588558891015163

# %%
import matplotlib.pyplot as plt
plt.imshow(field[0,:,:])

# %%
test_data_2=xr.open_dataset("/cluster/work/climate/dnikolo/CLAAS_Data/sample_2024/CPH/ORD57534/CPPin20241001000000405SVMSGI1UD.nc")
field_2=test_data_2.variables["cph"].data

# %%
plt.imshow(field_2[0,:,:])
